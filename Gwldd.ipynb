# %%
# IMPORTS
import os
import sys
import polars as pl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import warnings
from dash import Dash
import plotly.graph_objects as go
from scipy.stats import genextreme
import logging
import re
from pathlib import Path

# Install required packages
from src.install_packages import install_requirements
install_requirements()
# Out:
# Groundwater Analysis Tool - Package Installation
# ============================================================
# Checking and installing required packages...
# ============================================================
# Found c:\Users\oluwunmi\Desktop\Ground_Insight\requirements.txt, installing packages...
# ✓ All packages installed from requirements.txt
# True

# %%
# CONFIGURATION
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
warnings.filterwarnings('ignore')

# %%
# UNIT CONVERSION SETTINGS
CONVERT_MM_TO_METERS = False  # Set to True to convert water measurements from mm to meters

# DATA PROCESSING SETTINGS
REMOVE_DUPLICATES = False  # Set to False to keep all duplicate records, True to remove duplicates

# PATHS AND SETTINGS — edit PROJECT_ROOT if Jupyter was not started in this folder
PROJECT_ROOT = Path.cwd()  # or Path(r"C:\Users\oluwunmi\Desktop\Ground_Insight")

module_path = str(PROJECT_ROOT)
data_folder = str(PROJECT_ROOT)
groundwater_filename = 'DunTestData.csv'   # your file; not included on GitHub
rainfall_filename = 'DunRain.csv'
mapping_filename = 'None'
csv_folder_path = str(PROJECT_ROOT / 'folder_mode_data')
use_folder_mode = False
use_large_dataset_mode = False
large_dataset_path = str(PROJECT_ROOT / 'large_dataset')

if module_path not in sys.path:
    sys.path.insert(0, module_path)

# %%
# MAIN EXECUTION MODULE
from src.main import main_unified as _main_unified

# Wrapper function to use global variables from Cell 2
def main_unified():
    global data, well_columns, mapping_dict
    data, well_columns, mapping_dict, quality_dfs = _main_unified(
        use_folder_mode=use_folder_mode,
        csv_folder_path=csv_folder_path,
        rainfall_filename=rainfall_filename,
        mapping_filename=mapping_filename,
        use_large_dataset_mode=use_large_dataset_mode,
        large_dataset_path=large_dataset_path,
        groundwater_filename=groundwater_filename,
        data_folder=data_folder,
        CONVERT_MM_TO_METERS=CONVERT_MM_TO_METERS,
        REMOVE_DUPLICATES=REMOVE_DUPLICATES
    )
    return data, well_columns, mapping_dict

# Execute main function
if __name__ == "__main__":
    main_unified()
# Out:
# ============================================================
# GROUNDWATER ANALYSIS TOOL - UNIFIED MODE
# ============================================================
#
#  SINGLE FILE MODE: Loading data from DunTestData.csv
#   Loading rainfall data from: DunRain.csv
# Loading groundwater data from: DunTestData.csv
# Detected data format: wide
# 2026-06-23 10:52:38,289 - INFO - Successfully parsed DateTime using format: %d/%m/%Y %H:%M (163301/163301 valid dates)
# 2026-06-23 10:52:38,296 - INFO - Duplicate removal is DISABLED - keeping all records
# Loading rainfall data from: DunRain.csv
# 2026-06-23 10:52:38,547 - INFO - Initial rainfall data from polars: 244826 rows
# 2026-06-23 10:52:38,629 - INFO - After extracting start dates: 244826 rows
# 2026-06-23 10:52:39,367 - INFO - Successfully parsed rainfall DateTime using format: %d/%m/%Y %H:%M
# 2026-06-23 10:52:39,370 - INFO - After datetime conversion: 244826 rows, 244825 valid dates
# 2026-06-23 10:52:39,377 - INFO - Successfully parsed 'From X to Y' datetime format
# 2026-06-23 10:52:39,542 - INFO - Rainfall data merged successfully. 244826/326521 rows have rainfall data.
# 2026-06-23 10:52:39,570 - INFO - Data loaded successfully: 4 wells, 326521 records
# ============================================================
# Select visualisation type:
# 1. Static Interactive Plot
# 2. Julian Plot
# 3. Subplots
# 4. Overlay
# 5. Monthly Statistics
# 6. Statistical Analysis
# 7. Extreme Value Analysis MAXIMA
# 8. Extreme Value Analysis POT
# 9. Wavelet Analysis
# 10. Batch Mann-Kendall Analysis
# 11. All
# 12. Exit
# ============================================================
#
# Launching Wavelet Analysis...
# Starting Wavelet Analysis Dashboard...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
